# %% [markdown]
# # introduction

# %% [markdown]
# In the next notebook, we will identify fruits with the help
#  transfer learning on the RESNET network trained on the data set Imagenet.
#
# Fruit 360 dataset is a collection of over 90,000 images of 131 different fruits.
# **Our model was able to classify them with over 96% success !!!**

# %% [markdown]
# # Import library

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import itertools
import warnings
warnings.filterwarnings("ignore")

# %%
# re-size all the images to this
IMAGE_SIZE = [100, 100] # feel free to change depending on dataset

# training config:
epochs = 16
batch_size = 128

# %%
train_path = 'Training'
valid_path = 'Test'

# %%
# useful for getting number of files
image_files = glob(train_path + '/*/*.jp*g')
valid_image_files = glob(valid_path + '/*/*.jp*g')

# %%
# useful for getting number of classes
folders = glob(train_path + '/*')

# %%
# look at an image for fun
plt.imshow(image.load_img(np.random.choice(image_files)));

# %%
# resnet base
res = InceptionV3(
    input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 47s 1us/step
# 87924736/87910968 [==============================] - 47s 1us/step

# %%
# don't train existing weights
for layer in res.layers:
  layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(res.output)
# x = Dense(1000, activation='relu')(x) # example
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=res.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_98 (Conv2D)             (None, 49, 49, 32)   864         ['input_3[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 49, 49, 32)  96          ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 49, 49, 32)   0           ['batch_normalization_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 47, 47, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 47, 47, 32)  96          ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 47, 47, 32)   0           ['batch_normalization_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 47, 47, 64)   18432       ['activation_95[0][0]']
#
#  batch_normalization_100 (Batch  (None, 47, 47, 64)  192         ['conv2d_100[0][0]']
#  Normalization)
#
#  activation_96 (Activation)     (None, 47, 47, 64)   0           ['batch_normalization_100[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 23, 23, 64)  0           ['activation_96[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 23, 23, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_101 (Batch  (None, 23, 23, 80)  240         ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_97 (Activation)     (None, 23, 23, 80)   0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 21, 21, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_102 (Batch  (None, 21, 21, 192)  576        ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 21, 21, 192)  0           ['batch_normalization_102[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 10, 10, 192)  0          ['activation_98[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 10, 10, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_106 (Batch  (None, 10, 10, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_106[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 10, 10, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_104 (Batch  (None, 10, 10, 48)  144         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 10, 10, 96)  288         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_104[0][0]']
#
#  activation_103 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_107[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 10, 10, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_103 (Conv2D)            (None, 10, 10, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 10, 10, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_103 (Batch  (None, 10, 10, 64)  192         ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 10, 10, 64)  192         ['conv2d_105[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 10, 10, 96)  288         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_109 (Batch  (None, 10, 10, 32)  96          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_103[0][0]']
#
#  activation_101 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_105[0][0]']
#
#  activation_104 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_108[0][0]']
#
#  activation_105 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_109[0][0]']
#
#  mixed0 (Concatenate)           (None, 10, 10, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 10, 10, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_113 (Batch  (None, 10, 10, 64)  192         ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_113[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 10, 10, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_111 (Batch  (None, 10, 10, 48)  144         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 10, 10, 96)  288         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_111[0][0]']
#
#  activation_110 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_114[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 10, 10, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_110 (Conv2D)            (None, 10, 10, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 10, 10, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_110 (Batch  (None, 10, 10, 64)  192         ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 10, 10, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 10, 10, 96)  288         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 10, 10, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_110[0][0]']
#
#  activation_108 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_112[0][0]']
#
#  activation_111 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_115[0][0]']
#
#  activation_112 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_116[0][0]']
#
#  mixed1 (Concatenate)           (None, 10, 10, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_120 (Batch  (None, 10, 10, 64)  192         ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_120[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 10, 10, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_118 (Batch  (None, 10, 10, 48)  144         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_121 (Batch  (None, 10, 10, 96)  288         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_118[0][0]']
#
#  activation_117 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_121[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 10, 10, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_117 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 10, 10, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_117 (Batch  (None, 10, 10, 64)  192         ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 10, 10, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 10, 10, 96)  288         ['conv2d_122[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 10, 10, 64)  192         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_117[0][0]']
#
#  activation_115 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_119[0][0]']
#
#  activation_118 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_122[0][0]']
#
#  activation_119 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_123[0][0]']
#
#  mixed2 (Concatenate)           (None, 10, 10, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_125 (Batch  (None, 10, 10, 64)  192         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_125[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_126 (Batch  (None, 10, 10, 96)  288         ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_126[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 4, 4, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 4, 4, 96)     82944       ['activation_122[0][0]']
#
#  batch_normalization_124 (Batch  (None, 4, 4, 384)   1152        ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 4, 4, 96)    288         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_124[0][0]']
#
#  activation_123 (Activation)    (None, 4, 4, 96)     0           ['batch_normalization_127[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 4, 4, 768)    0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 4, 4, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_132 (Batch  (None, 4, 4, 128)   384         ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_132[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_128[0][0]']
#
#  batch_normalization_133 (Batch  (None, 4, 4, 128)   384         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_133[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 4, 4, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_129[0][0]']
#
#  batch_normalization_129 (Batch  (None, 4, 4, 128)   384         ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_134 (Batch  (None, 4, 4, 128)   384         ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_129[0][0]']
#
#  activation_130 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_134[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_125[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_130[0][0]']
#
#  batch_normalization_130 (Batch  (None, 4, 4, 128)   384         ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_135 (Batch  (None, 4, 4, 128)   384         ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_130[0][0]']
#
#  activation_131 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_135[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 4, 4, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_128 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 4, 4, 192)    172032      ['activation_126[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 4, 4, 192)    172032      ['activation_131[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_128 (Batch  (None, 4, 4, 192)   576         ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 4, 4, 192)   576         ['conv2d_131[0][0]']
#  Normalization)
#
#  batch_normalization_136 (Batch  (None, 4, 4, 192)   576         ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 4, 4, 192)   576         ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_128[0][0]']
#
#  activation_127 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_131[0][0]']
#
#  activation_132 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_136[0][0]']
#
#  activation_133 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_137[0][0]']
#
#  mixed4 (Concatenate)           (None, 4, 4, 768)    0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_142 (Batch  (None, 4, 4, 160)   480         ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_142[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_138[0][0]']
#
#  batch_normalization_143 (Batch  (None, 4, 4, 160)   480         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_143[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_139[0][0]']
#
#  batch_normalization_139 (Batch  (None, 4, 4, 160)   480         ['conv2d_139[0][0]']
#  Normalization)
#
#  batch_normalization_144 (Batch  (None, 4, 4, 160)   480         ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_139[0][0]']
#
#  activation_140 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_135[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_140[0][0]']
#
#  batch_normalization_140 (Batch  (None, 4, 4, 160)   480         ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 4, 4, 160)   480         ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_140[0][0]']
#
#  activation_141 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_145[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 4, 4, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_138 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_136[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_141[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_138 (Batch  (None, 4, 4, 192)   576         ['conv2d_138[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 4, 4, 192)   576         ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_146 (Batch  (None, 4, 4, 192)   576         ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 4, 4, 192)   576         ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_138[0][0]']
#
#  activation_137 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_141[0][0]']
#
#  activation_142 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_146[0][0]']
#
#  activation_143 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_147[0][0]']
#
#  mixed5 (Concatenate)           (None, 4, 4, 768)    0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_152 (Batch  (None, 4, 4, 160)   480         ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_152[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_148[0][0]']
#
#  batch_normalization_153 (Batch  (None, 4, 4, 160)   480         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_149[0][0]']
#
#  batch_normalization_149 (Batch  (None, 4, 4, 160)   480         ['conv2d_149[0][0]']
#  Normalization)
#
#  batch_normalization_154 (Batch  (None, 4, 4, 160)   480         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_149[0][0]']
#
#  activation_150 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_145[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_150[0][0]']
#
#  batch_normalization_150 (Batch  (None, 4, 4, 160)   480         ['conv2d_150[0][0]']
#  Normalization)
#
#  batch_normalization_155 (Batch  (None, 4, 4, 160)   480         ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_150[0][0]']
#
#  activation_151 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_155[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 4, 4, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_148 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_146[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_151[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_148 (Batch  (None, 4, 4, 192)   576         ['conv2d_148[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 4, 4, 192)   576         ['conv2d_151[0][0]']
#  Normalization)
#
#  batch_normalization_156 (Batch  (None, 4, 4, 192)   576         ['conv2d_156[0][0]']
#  Normalization)
#
#  batch_normalization_157 (Batch  (None, 4, 4, 192)   576         ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_148[0][0]']
#
#  activation_147 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_151[0][0]']
#
#  activation_152 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_156[0][0]']
#
#  activation_153 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_157[0][0]']
#
#  mixed6 (Concatenate)           (None, 4, 4, 768)    0           ['activation_144[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_152[0][0]',
#                                                                   'activation_153[0][0]']
#
# ...
#  conv2d_178 (Conv2D)            (None, 1, 1, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_178 (Batch  (None, 1, 1, 448)   1344        ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_174 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_178[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 1, 1, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_175 (Batch  (None, 1, 1, 384)   1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  batch_normalization_179 (Batch  (None, 1, 1, 384)   1152        ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_175[0][0]']
#
#  activation_175 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_179[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 1, 1, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_174 (Conv2D)            (None, 1, 1, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_176 (Batch  (None, 1, 1, 384)   1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 1, 1, 384)   1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  batch_normalization_180 (Batch  (None, 1, 1, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 1, 1, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  conv2d_182 (Conv2D)            (None, 1, 1, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_174 (Batch  (None, 1, 1, 320)   960         ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_173 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_177[0][0]']
#
#  activation_176 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_177 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_181[0][0]']
#
#  batch_normalization_182 (Batch  (None, 1, 1, 192)   576         ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_174[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 1, 1, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 1, 1, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_182[0][0]']
#
#  mixed9 (Concatenate)           (None, 1, 1, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 1, 1, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_187 (Batch  (None, 1, 1, 448)   1344        ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_187[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 1, 1, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_184 (Batch  (None, 1, 1, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  batch_normalization_188 (Batch  (None, 1, 1, 384)   1152        ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_184[0][0]']
#
#  activation_184 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 1, 1, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_183 (Conv2D)            (None, 1, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_185 (Batch  (None, 1, 1, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 1, 1, 384)   1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  batch_normalization_189 (Batch  (None, 1, 1, 384)   1152        ['conv2d_189[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 1, 1, 384)   1152        ['conv2d_190[0][0]']
#  Normalization)
#
#  conv2d_191 (Conv2D)            (None, 1, 1, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_183 (Batch  (None, 1, 1, 320)   960         ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_182 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_186[0][0]']
#
#  activation_185 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_189[0][0]']
#
#  activation_186 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_190[0][0]']
#
#  batch_normalization_191 (Batch  (None, 1, 1, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_183[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 1, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 1, 1, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_191[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 1, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['mixed10[0][0]']
#
#  dense (Dense)                  (None, 131)          268419      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 22,071,203
# Trainable params: 268,419
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='sparse_categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# create an instance of ImageDataGenerator
train_gen = ImageDataGenerator(
  rotation_range=20,
  width_shift_range=0.1,
  height_shift_range=0.1,
  shear_range=0.1,
  zoom_range=0.2,
  horizontal_flip=True,
  vertical_flip=True,
  preprocessing_function=preprocess_input
)

val_gen = ImageDataGenerator(
  preprocessing_function=preprocess_input
)

# %%
# test generator to see how it works and some other useful things

# get label mapping for confusion matrix plot later
test_gen = val_gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE)
print(test_gen.class_indices)
labels = [None] * len(test_gen.class_indices)
for k, v in test_gen.class_indices.items():
  labels[v] = k
# Out:
# Found 22688 images belonging to 131 classes.
# {'Apple Braeburn': 0, 'Apple Crimson Snow': 1, 'Apple Golden 1': 2, 'Apple Golden 2': 3, 'Apple Golden 3': 4, 'Apple Granny Smith': 5, 'Apple Pink Lady': 6, 'Apple Red 1': 7, 'Apple Red 2': 8, 'Apple Red 3': 9, 'Apple Red Delicious': 10, 'Apple Red Yellow 1': 11, 'Apple Red Yellow 2': 12, 'Apricot': 13, 'Avocado': 14, 'Avocado ripe': 15, 'Banana': 16, 'Banana Lady Finger': 17, 'Banana Red': 18, 'Beetroot': 19, 'Blueberry': 20, 'Cactus fruit': 21, 'Cantaloupe 1': 22, 'Cantaloupe 2': 23, 'Carambula': 24, 'Cauliflower': 25, 'Cherry 1': 26, 'Cherry 2': 27, 'Cherry Rainier': 28, 'Cherry Wax Black': 29, 'Cherry Wax Red': 30, 'Cherry Wax Yellow': 31, 'Chestnut': 32, 'Clementine': 33, 'Cocos': 34, 'Corn': 35, 'Corn Husk': 36, 'Cucumber Ripe': 37, 'Cucumber Ripe 2': 38, 'Dates': 39, 'Eggplant': 40, 'Fig': 41, 'Ginger Root': 42, 'Granadilla': 43, 'Grape Blue': 44, 'Grape Pink': 45, 'Grape White': 46, 'Grape White 2': 47, 'Grape White 3': 48, 'Grape White 4': 49, 'Grapefruit Pink': 50, 'Grapefruit White': 51, 'Guava': 52, 'Hazelnut': 53, 'Huckleberry': 54, 'Kaki': 55, 'Kiwi': 56, 'Kohlrabi': 57, 'Kumquats': 58, 'Lemon': 59, 'Lemon Meyer': 60, 'Limes': 61, 'Lychee': 62, 'Mandarine': 63, 'Mango': 64, 'Mango Red': 65, 'Mangostan': 66, 'Maracuja': 67, 'Melon Piel de Sapo': 68, 'Mulberry': 69, 'Nectarine': 70, 'Nectarine Flat': 71, 'Nut Forest': 72, 'Nut Pecan': 73, 'Onion Red': 74, 'Onion Red Peeled': 75, 'Onion White': 76, 'Orange': 77, 'Papaya': 78, 'Passion Fruit': 79, 'Peach': 80, 'Peach 2': 81, 'Peach Flat': 82, 'Pear': 83, 'Pear 2': 84, 'Pear Abate': 85, 'Pear Forelle': 86, 'Pear Kaiser': 87, 'Pear Monster': 88, 'Pear Red': 89, 'Pear Stone': 90, 'Pear Williams': 91, 'Pepino': 92, 'Pepper Green': 93, 'Pepper Orange': 94, 'Pepper Red': 95, 'Pepper Yellow': 96, 'Physalis': 97, 'Physalis with Husk': 98, 'Pineapple': 99, 'Pineapple Mini': 100, 'Pitahaya Red': 101, 'Plum': 102, 'Plum 2': 103, 'Plum 3': 104, 'Pomegranate': 105, 'Pomelo Sweetie': 106, 'Potato Red': 107, 'Potato Red Washed': 108, 'Potato Sweet': 109, 'Potato White': 110, 'Quince': 111, 'Rambutan': 112, 'Raspberry': 113, 'Redcurrant': 114, 'Salak': 115, 'Strawberry': 116, 'Strawberry Wedge': 117, 'Tamarillo': 118, 'Tangelo': 119, 'Tomato 1': 120, 'Tomato 2': 121, 'Tomato 3': 122, 'Tomato 4': 123, 'Tomato Cherry Red': 124, 'Tomato Heart': 125, 'Tomato Maroon': 126, 'Tomato Yellow': 127, 'Tomato not Ripened': 128, 'Walnut': 129, 'Watermelon': 130}

# %%
# should be a strangely colored image (due to VGG weights being BGR)
for x, y in test_gen:
  print("min:", x[0].min(), "max:", x[0].max())
  plt.title(labels[np.argmax(y[0])])
  plt.imshow(x[0])
  plt.show()
  break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -0.99215686 max: 1.0

# %%
# create generators
train_generator = train_gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
  class_mode='sparse',
)
valid_generator = val_gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=False,
  batch_size=batch_size,
  class_mode='sparse',
)
# Out:
# Found 67692 images belonging to 131 classes.
# Found 22688 images belonging to 131 classes.

# %%
# fit the model
r = model.fit(
  train_generator,
  validation_data=valid_generator,
  epochs=epochs,
  steps_per_epoch=len(image_files) // batch_size,
  validation_steps=len(valid_image_files) // batch_size,
)
# Out:
# Epoch 1/16
# 528/528 [==============================] - 1275s 2s/step - loss: 1.0283 - accuracy: 0.7433 - val_loss: 0.6663 - val_accuracy: 0.8110
# Epoch 2/16
# 528/528 [==============================] - 1087s 2s/step - loss: 0.4182 - accuracy: 0.8788 - val_loss: 0.5129 - val_accuracy: 0.8580
# Epoch 3/16
# 528/528 [==============================] - 1068s 2s/step - loss: 0.3312 - accuracy: 0.9013 - val_loss: 0.5419 - val_accuracy: 0.8442
# Epoch 4/16
# 528/528 [==============================] - 1071s 2s/step - loss: 0.2898 - accuracy: 0.9126 - val_loss: 0.4863 - val_accuracy: 0.8609
# Epoch 5/16
# 528/528 [==============================] - 1075s 2s/step - loss: 0.2564 - accuracy: 0.9210 - val_loss: 0.4319 - val_accuracy: 0.8803
# Epoch 6/16
# 528/528 [==============================] - 1129s 2s/step - loss: 0.2429 - accuracy: 0.9247 - val_loss: 0.4497 - val_accuracy: 0.8749
# Epoch 7/16
# 528/528 [==============================] - 1127s 2s/step - loss: 0.2308 - accuracy: 0.9275 - val_loss: 0.4188 - val_accuracy: 0.8908
# Epoch 8/16
# 528/528 [==============================] - 1079s 2s/step - loss: 0.2213 - accuracy: 0.9306 - val_loss: 0.3935 - val_accuracy: 0.8923
# Epoch 9/16
# 528/528 [==============================] - 1082s 2s/step - loss: 0.2115 - accuracy: 0.9345 - val_loss: 0.4577 - val_accuracy: 0.8844
# Epoch 10/16
# 528/528 [==============================] - 1084s 2s/step - loss: 0.2042 - accuracy: 0.9354 - val_loss: 0.3966 - val_accuracy: 0.8938
# Epoch 11/16
# 528/528 [==============================] - 1087s 2s/step - loss: 0.1924 - accuracy: 0.9395 - val_loss: 0.4726 - val_accuracy: 0.8876
# Epoch 12/16
# 528/528 [==============================] - 1166s 2s/step - loss: 0.1922 - accuracy: 0.9396 - val_loss: 0.4206 - val_accuracy: 0.8903
# Epoch 13/16
# 528/528 [==============================] - 1105s 2s/step - loss: 0.1847 - accuracy: 0.9417 - val_loss: 0.4242 - val_accuracy: 0.8938
# Epoch 14/16
# 528/528 [==============================] - 1092s 2s/step - loss: 0.1816 - accuracy: 0.9434 - val_loss: 0.4533 - val_accuracy: 0.8866
# Epoch 15/16
# 528/528 [==============================] - 1091s 2s/step - loss: 0.1805 - accuracy: 0.9430 - val_loss: 0.4678 - val_accuracy: 0.8920
# Epoch 16/16
# 528/528 [==============================] - 1089s 2s/step - loss: 0.1738 - accuracy: 0.9452 - val_loss: 0.4178 - val_accuracy: 0.8949

# %%
# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
def get_confusion_matrix(data_path, N):
  # we need to see the data in the same order
  # for both predictions and targets
  print("Generating confusion matrix", N)
  predictions = []
  targets = []
  i = 0
  n_images = 0
  for x, y in val_gen.flow_from_directory(
      data_path,
      target_size=IMAGE_SIZE,
      shuffle=False,
      batch_size=batch_size * 2):
    i += 1
    n_images += len(y)
    if i % 50 == 0:
      print(f'{n_images} images processed.')
    p = model.predict(x)
    p = np.argmax(p, axis=1)
    y = np.argmax(y, axis=1)
    predictions = np.concatenate((predictions, p))
    targets = np.concatenate((targets, y))
    if len(targets) >= N:
      break

  cm = confusion_matrix(targets, predictions)
  return cm

# %%
cm = get_confusion_matrix(train_path, len(image_files))
print(cm)
# Out:
# Generating confusion matrix 67692
# Found 67692 images belonging to 131 classes.
# 12800 images processed.
# 25600 images processed.
# 38400 images processed.
# 51200 images processed.
# 64000 images processed.
# [[347   1   0 ...   0   0   0]
#  [  0 430   0 ...   0   0   0]
#  [  0   0 477 ...   0   0   0]
#  ...
#  [  0   0   0 ... 468   0   0]
#  [  0   0   0 ...   0 735   0]
#  [  0   0   0 ...   0   0 475]]

# %%
valid_cm = get_confusion_matrix(valid_path, len(valid_image_files))
print(valid_cm)
# Out:
# Generating confusion matrix 22688
# Found 22688 images belonging to 131 classes.
# 12800 images processed.
# [[ 95   0   0 ...   0   0   0]
#  [  0 119   0 ...   0   0   0]
#  [  0   0 158 ...   0   0   0]
#  ...
#  [  0   0   0 ... 147   0   0]
#  [  0   0   0 ...   0 248   0]
#  [  0   0   0 ...   0   0 157]]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.figure(figsize=(30, 30))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
plot_confusion_matrix(cm, labels, title='Train confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[347   1   0 ...   0   0   0]
#  [  0 430   0 ...   0   0   0]
#  [  0   0 477 ...   0   0   0]
#  ...
#  [  0   0   0 ... 468   0   0]
#  [  0   0   0 ...   0 735   0]
#  [  0   0   0 ...   0   0 475]]

# %%
plot_confusion_matrix(valid_cm, labels, title='Validation confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 95   0   0 ...   0   0   0]
#  [  0 119   0 ...   0   0   0]
#  [  0   0 158 ...   0   0   0]
#  ...
#  [  0   0   0 ... 147   0   0]
#  [  0   0   0 ...   0 248   0]
#  [  0   0   0 ...   0   0 157]]

# %%
model.save('my_mode.h5')

# %%
ls
# Out:
# MobileNetV2 copy.ipynb  Test/                   my_mode.h5
# MobileNetV2.ipynb       Training/
